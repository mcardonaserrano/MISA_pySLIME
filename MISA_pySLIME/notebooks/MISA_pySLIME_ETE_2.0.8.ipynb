# %% [markdown]
# # MISA Extract Transform & Engineer (ETE) Pipeline
#
# This notebook implements a full end-to-end workflow for building a binned‐regression ionospheric background model from Millstone Hill Incoherent Scatter Radar (MISA) data:
#
# 1. **Data Extraction & Loading**
#    - Reads raw MISA HDF5 scan groups (timestamps, range, ne/ti/tr, etc.)
#    - Ingests and resamples ancillary geophysical indices (Hp, Ap, Kp, Dst, SME, FISM2) into a unified 30 min timeline
#
# 2. **Cleaning & Filtering**
#    - Masks out eclipse/extreme days and bad‐quality radar returns
#    - Removes outliers via relative‐error, standard‐deviation, and percentile‐based filters
#    - Applies NaN masking to bad points
#
# 3. **Transformation & Feature Engineering**
#    - Flattens the (time × range) grid to a tabular DataFrame
#    - Computes and reindexes solar-local time (SLT), geomagnetic lat/lon, and time-lagged indices
#    - Generates cyclical features (sin/cos of UT, SLT, DOY), powers/interactions, and log–transformations
#
# 4. **Binned Regression Training**
#    - Defines equal‐sized bins in azimuth and altitude
#    - Within each bin, scales inputs, fits a degree-4 polynomial Ridge regression for the target (ne, ti, te)
#    - Stores per-bin models (scaler, transformer, regressor) for fast lookup
#
# Use this notebook to reproduce the full model products ionospheric background modeling used in MISA_pySLIME_query.

# %% [markdown]
# ## 0. Loading Libraries and Defining Functions

# %%
# importing libraries
import matplotlib.pyplot as plt
from tqdm import tqdm
from pathlib import Path
import pandas as pd
import xarray as xr
import numpy as np
import netCDF4
import h5py
import dask

# dirs
group_name = 'Array_with_kinst=31.0_and_mdtyp=115.0_and_pl=0.002' # MISA instrument data group name
misa_dir = '../ancillary/data_products/MadrigalLib' #data product dir
# geophysical ancillary data dirs
hp_ap_dir = '../ancillary/geophysical_ancillary/Hp30_ap30_complete_series.txt'
kp_f107_dir = '../ancillary/geophysical_ancillary/Kp_ap_Ap_SN_F107_since_1932.txt'
fism2_dir = '../ancillary/geophysical_ancillary/fism2/60s/'
ae_dir = '../ancillary/geophysical_ancillary/supermag_ae.csv'
dst_dir = '../ancillary/geophysical_ancillary/dst2000to2025.txt'

# %%
# defining functions
def std_column_filter_indices(a, nbstd):
    """
    Identify outlier entries in each column of a 2D array.

    Marks any point more than `nbstd` standard deviations from the column mean.

    Parameters
    ----------
    a : ndarray, shape (n_rows, n_cols)
        Data matrix where rows are observations and columns are variables.
    nbstd : float
        Number of standard deviations beyond which a point is considered bad.

    Returns
    -------
    bad_indices : list of (row, col) tuples
        Coordinates of all detected outlier points.
    """
    bad_indices = []
    for col in range(a.shape[1]):
        col_mean = np.nanmean(a[:, col])
        col_std  = np.nanstd(a[:, col])
        # rows that exceed the threshold in either direction
        mask = ((a[:, col] > col_mean + nbstd*col_std) |
                (a[:, col] < col_mean - nbstd*col_std))
        bad_rows = np.where(mask)[0]
        bad_indices.extend([(row, col) for row in bad_rows])
    return bad_indices


def apply_interpolation(data, bad_indices):
    """
    Linearly interpolate over flagged bad entries.

    For each column with bad indices, sets those to NaN, then fills
    them by 1D linear interpolation of the remaining valid data.

    Parameters
    ----------
    data : ndarray, shape (n_rows, n_cols)
        Original data array (will be modified in-place).
    bad_indices : list of (row, col) tuples
        Points to replace via interpolation.

    Returns
    -------
    data : ndarray
        Array with bad points replaced by linear interpolation.
    """
    for col in np.unique([c for _, c in bad_indices]):
        # mask out the bad points
        col_data = data[:, col].copy()
        bad_rows = [r for r, c in bad_indices if c == col]
        col_data[bad_rows] = np.nan
        # only interpolate if there's at least two valid points
        valid = ~np.isnan(col_data)
        if valid.sum() > 1:
            col_data[bad_rows] = np.interp(
                bad_rows, np.where(valid)[0], col_data[valid]
            )
        data[:, col] = col_data
    return data


def apply_nonlinear_interpolation(data, bad_indices, kind='cubic'):
    """
    Replace bad entries via higher-order (cubic, quadratic, etc.) interpolation.

    Parameters
    ----------
    data : ndarray, shape (n_rows, n_cols)
        Original data array.
    bad_indices : list of (row, col) tuples
        Locations to fill.
    kind : str, default 'cubic'
        Interpolation method passed to scipy.interpolate.interp1d.

    Returns
    -------
    data : ndarray
        Array with bad points estimated by nonlinear interpolation.
    """
    for col in np.unique([c for _, c in bad_indices]):
        col_data = data[:, col]
        valid_idx   = np.where(~np.isnan(col_data))[0]
        invalid_idx = np.where(np.isnan(col_data))[0]
        # only proceed if enough valid points exist
        if valid_idx.size > 1:
            interp_fn = interp1d(
                valid_idx, col_data[valid_idx],
                kind=kind, fill_value='extrapolate'
            )
            col_data[invalid_idx] = interp_fn(invalid_idx)
        data[:, col] = col_data
    return data


def apply_nans(data, bad_indices):
    """
    Mask out bad data points by setting them to NaN.

    Parameters
    ----------
    data : ndarray, shape (n_rows, n_cols)
        Original data array.
    bad_indices : list of (row, col) tuples
        Points to invalidate.

    Returns
    -------
    data : ndarray
        Array with specified entries set to NaN.
    """
    for row, col in bad_indices:
        data[row, col] = np.nan
    return data


def load_datasets_with_timestamp_and_range(
    file_path, target_kinst, target_mdtyp, target_pl
):
    """
    Load an HDF5 group matching given instrument/type/parameter, returning an
    xarray.Dataset indexed by real timestamps and range.

    Parameters
    ----------
    file_path : str
        Path to the .hdf5 file.
    target_kinst : float
        Instrument code to match in group key.
    target_mdtyp : float
        Measurement type code.
    target_pl : float
        Physical parameter code.

    Returns
    -------
    ds : xarray.Dataset
        Contains variables at dims ('dates', 'range'), plus coords:
        - 'doy' (day-of-year)
        - 'dates' (datetime64 index).
    """
    with h5py.File(file_path, 'r') as f:
        # locate the matching group by parsing its key
        group_name = None
        for key in f.keys():
            if not key.startswith('Array_with_'): continue
            attrs = dict(p.split('=') for p in key.replace('Array_with_', '').split('_and_'))
            if (float(attrs.get('kinst', -1)) == target_kinst and
                float(attrs.get('mdtyp', -1)) == target_mdtyp and
                float(attrs.get('pl',    -1)) == target_pl):
                group_name = key
                break
        if group_name is None:
            print(f'No matching group for kinst={target_kinst}, mdtyp={target_mdtyp}, pl={target_pl}')
            return np.nan

        grp = f[group_name]
        timestamps = grp['timestamps'][()]
        ranges     = grp['range'][()]

        data_vars = {
            'range':     ('range',     ranges),
            'doy':       None  # will add after coords
        }
        # load each dataset, assigning dims based on shape
        for name, obj in grp.items():
            if name in ('timestamps', 'range'): continue
            arr = obj[()]
            if arr.ndim == 1 and arr.size == timestamps.size:
                data_vars[name] = ('timestamp', arr)
            elif arr.ndim == 2 and arr.shape == (timestamps.size, ranges.size):
                data_vars[name] = (('timestamp','range'), arr)

        # build xarray Dataset and swap to datetime index
        ds = xr.Dataset(data_vars)
        dates = pd.to_datetime(timestamps, unit='s')
        ds = ds.assign_coords(dates=('timestamp', dates)).swap_dims({'timestamp':'dates'})
        # add day-of-year coordinate for feature engineering
        ds['doy'] = ('dates', ds['dates'].dt.dayofyear.values)
    return ds

import os
def concatenate_hdf5_files_in_directory(
    directory_path, target_kinst, target_mdtyp, target_pl
):
    """
    Selects the highest‐revision HDF5 per day for given parameters, then
    concatenates them into one Dataset along the 'dates' dimension.

    Parameters
    ----------
    directory_path : str
        Folder containing .hdf5 files.
    target_kinst, target_mdtyp, target_pl : floats
        Matching criteria for groups within each file.

    Returns
    -------
    concatenated : xarray.Dataset
        Combined time series of all selected files.
    """
    # pick only the latest revision for each base filename
    best = {}
    for fn in os.listdir(directory_path):
        if not fn.endswith('.hdf5'): continue
        parts = fn.split('.')
        base, rev = ('.'.join(parts[:-2]), int(parts[-2])) if parts[-2].isdigit() else (fn, -1)
        if base not in best or rev > best[base][0]:
            best[base] = (rev, fn)

    datasets = []
    for _, fn in sorted(best.values(), key=lambda x: x[1]):
        print(f"Loading {fn}...")
        path = os.path.join(directory_path, fn)
        ds = load_datasets_with_timestamp_and_range(path, target_kinst, target_mdtyp, target_pl)
        if isinstance(ds, xr.Dataset):
            datasets.append(ds)
    if not datasets:
        raise RuntimeError("No valid datasets to concatenate.")
    # merge all along the time axis
    concatenated = xr.concat(datasets, dim='dates')
    return concatenated

def create_geophysical_index_xr(
    hp_ap_dir, kp_f107_dir, dst_dir, supermag_ae_csv, fism2_1min_dir
):
    """
    Reads and merges multiple geophysical indices onto a uniform 30-minute timeline:
      - Hp30 & ap30 from MJD-based ascii files
      - Adjusted F10.7 flux and expanded 3-h Kp values
      - Dst index from hourly ascii
      - SME from SuperMAG AE CSV (1-min → 30-min max)
      - FISM2 irradiance (1-min netCDF → 30-min max)
    Returns:
        xr.Dataset with coords 'dates' (30-min) and data_vars:
          ut, hp30, ap30, f107, kp, dst, sme, fism2
    """
    # 1) LOAD Hp30 & ap30
    hp_ap_df = pd.read_csv(
        hp_ap_dir,
        delim_whitespace=True,
        skiprows=30,   # header offset in ascii file
        header=None,
        names=['YYYY','MM','DD','hh.h','hh._m','days','d_m','Hp30','ap30','D']
    )
    # build datetime index from separate columns
    hp_ap_df['date'] = pd.to_datetime({
        'year':  hp_ap_df['YYYY'],
        'month': hp_ap_df['MM'],
        'day':   hp_ap_df['DD'],
        'hour':  hp_ap_df['hh.h']
    })
    hp_series = hp_ap_df.set_index('date')['Hp30']
    ap_series = hp_ap_df.set_index('date')['ap30']

    # 2) LOAD Kp & adjusted F10.7
    f10_kp_df = pd.read_csv(
        kp_f107_dir,
        delim_whitespace=True,
        skiprows=40,
        header=None,
        names=[
            'YYYY','MM','DD','days','days_m','BSR','dB',
            'Kp1','Kp2','Kp3','Kp4','Kp5','Kp6','Kp7','Kp8',
            'ap1','ap2','ap3','ap4','ap5','ap6','ap7','ap8',
            'Ap','SN','F10.7obs','F10.7adj','D'
        ]
    )
    # replace sentinel -1 with NaN before processing
    f10_kp_df.replace(-1, np.nan, inplace=True)
    # create a daily datetime index for F10.7
    f10_kp_df['date'] = pd.to_datetime({
        'year':  f10_kp_df['YYYY'],
        'month': f10_kp_df['MM'],
        'day':   f10_kp_df['DD']
    })
    f107_series = pd.Series(f10_kp_df['F10.7adj'].values,
                             index=f10_kp_df['date'])

    # expand 3-hourly Kp into 8 snapshots per day
    kp_intervals = pd.to_timedelta([0,3,6,9,12,15,18,21], unit='h')
    expanded = f10_kp_df.loc[f10_kp_df.index.repeat(8)].copy()
    # shift each repeat by the corresponding 3-h offset
    expanded['date'] += np.tile(kp_intervals, len(f10_kp_df))
    # flatten Kp1…Kp8 into a single series
    kp_cols = [f'Kp{i}' for i in range(1,9)]
    expanded['Kp'] = np.concatenate(
        [f10_kp_df[col].values for col in kp_cols]
    )
    kp_series = pd.Series(expanded['Kp'].values, index=expanded['date'])

    # 3) LOAD Dst index
    dst_df = pd.read_csv(dst_dir, delim_whitespace=True, comment='#')
    dst_df['datetime'] = pd.to_datetime(dst_df['DATE'] + ' ' + dst_df['TIME'])
    dst_series = pd.Series(dst_df['DST'].values, index=dst_df['datetime'])

    # 4) LOAD SME (1-min → 30-min max)
    sme_df = pd.read_csv(supermag_ae_csv, parse_dates=['Date_UTC'])
    sme_df.set_index('Date_UTC', inplace=True)
    sme_1m   = sme_df['SME']
    sme_30m  = sme_1m.resample('30T').max()

    # 5) LOAD & PROCESS FISM2 irradiance
    def fix_fism2_dataset(ds):
        # Drop old 'date' dim by converting YYYYDOY -> timestamp
        if 'date' in ds.coords and ds.dims.get('date',0)==1:
            raw = str(ds['date'].item()).strip()
            year, doy = int(raw[:4]), int(raw[4:])
            base = pd.Timestamp(year,1,1) + pd.Timedelta(days=doy-1)
            ds = ds.drop_vars('date')
        else:
            base = None
        # rename & convert 'utc' seconds to real time
        if 'utc' in ds.coords:
            ds = ds.rename(utc='time')
            if base is not None:
                ds['time'] = base + pd.to_timedelta(ds['time'], unit='s')
            ds = ds.assign_coords(time=ds['time'])
        # remove 'jd' index if present
        if 'jd' in ds.dims:    ds = ds.drop_dims('jd')
        if 'jd' in ds.coords:  ds = ds.drop_vars('jd')
        return ds

    files = sorted(Path(fism2_1min_dir).glob("FISM_60sec_*.nc"))
    if not files:
        raise FileNotFoundError(f"No FISM2 files in {fism2_1min_dir}")

    ds_fism2_1m = xr.open_mfdataset(
        files, combine='by_coords', preprocess=fix_fism2_dataset
    )
    # pick the 30.4 nm channel, then resample to 30-min max irradiance
    ds_fism2_1m = ds_fism2_1m.sel(wavelength=30.4, method='nearest')
    fism2_df_1m = ds_fism2_1m['irradiance'].to_dataframe()
    fism2_30m   = fism2_df_1m.resample('30T').max()

    # 6) BUILD THE COMMON 30-MIN TIMELINE
    all_starts = [
        hp_series.index.min(), ap_series.index.min(), f107_series.index.min(),
        kp_series.index.min(), dst_series.index.min(), sme_30m.index.min(),
        fism2_30m.index.min()
    ]
    all_ends   = [
        hp_series.index.max(), ap_series.index.max(), f107_series.index.max(),
        kp_series.index.max(), dst_series.index.max(), sme_30m.index.max(),
        fism2_30m.index.max()
    ]
    dates_full = pd.date_range(min(all_starts), max(all_ends), freq='30T')

    # 7) FORWARD-FILL each series onto the common timeline
    hp30_full  = hp_series.reindex(dates_full, method='ffill')
    ap30_full  = ap_series.reindex(dates_full, method='ffill')
    f107_full  = f107_series.reindex(dates_full, method='ffill')
    kp_full    = kp_series.reindex(dates_full, method='ffill')
    dst_full   = dst_series.reindex(dates_full, method='ffill')
    sme_full   = sme_30m.reindex(dates_full, method='ffill')
    fism2_full = fism2_30m['irradiance'].reindex(dates_full, method='ffill')

    # 8) COMPUTE solar local time (SLT) if needed, here we only output UT
    ut_full = [t.hour + t.minute/60 + t.second/3600 for t in dates_full]

    # 9) ASSEMBLE INTO AN xarray.Dataset
    ds_out = xr.Dataset({
        'ut':   ('dates', ut_full),
        'hp30': ('dates', hp30_full),
        'ap30': ('dates', ap30_full),
        'f107': ('dates', f107_full),
        'kp':   ('dates', kp_full),
        'dst':  ('dates', dst_full),
        'sme':  ('dates', sme_full),
        'fism2':('dates', fism2_full),
    }, coords={'dates': dates_full})

    return ds_out

# %% [markdown]
# ## 1. Data Extraction & Loading

# %%
### PROCESS MISA DATA ### (if already processed previously, skip this step)
# 1) Load & concatenate all relevant MISA HDF5 files into one xarray.Dataset
MISA_ds = concatenate_hdf5_files_in_directory(
    misa_dir,
    target_kinst=31.0,    # instrument code for MISA
    target_mdtyp=115.0,   # measurement type code for electron density etc.
    target_pl=0.002       # physical parameter code
)

# 2) Build boolean masks to remove data from unwanted scan regions:
#    • az_mask: restrict azimuth between densest region
#    • el_mask: only include beams at 6° elevation (both el1 and el2)
#    • gdalt_mask: keep ground‐to‐scatter distance between 0 and 1100 km
az_mask    = (MISA_ds.az1.data < -30) & (MISA_ds.az1.data >= -180)
el_mask    = (MISA_ds.el1.data == 6) & (MISA_ds.el2.data == 6)
gdalt_mask = (MISA_ds.gdalt.data > 0) & (MISA_ds.gdalt.data < 1100)

# 3) Apply each mask to every data variable (skip temporal coords 'doy' & 'slt'):
for mask in (el_mask, gdalt_mask, az_mask):
    for var in MISA_ds.data_vars:
        if var in ('doy', 'slt'):
            continue  # preserve DOY and SLT for later feature alignment
        data = MISA_ds[var]
        # Match mask dimensionality to the variable before masking:
        if data.ndim == mask.ndim:
            # same shape (e.g. 1D → 1D or 2D → 2D)
            MISA_ds[var] = data.where(mask)
        elif data.ndim < mask.ndim:
            # variable is lower‐dimensional (e.g. 1D var masked by 2D mask)
            MISA_ds[var] = data.where(mask.any(axis=1))
        else:
            # variable is higher‐dimensional (e.g. 2D var masked by 1D mask)
            MISA_ds[var] = data.where(mask[:, np.newaxis])

# 4) Sort by timestamp and compute decimal‐hour 'ut'
MISA_ds = MISA_ds.sortby('dates')
MISA_ds['ut'] = (
    MISA_ds['dates'].dt.hour +
    MISA_ds['dates'].dt.minute / 60 +
    MISA_ds['dates'].dt.second / 3600
)
MISA_ds['az_normalized'] = (['dates'],((MISA_ds.az1 + MISA_ds.az2) / 2).values)  # mean beam azimuth (n_times,)

# 5) Load master geophysical indices (Hp, Ap, Kp, Dst, SME, FISM2) on a 30-min grid
master_geo_ds = create_geophysical_index_xr(
    hp_ap_dir, kp_f107_dir, dst_dir, ae_dir, fism2_dir
)

# 6) Align (ffill) geophysical indices to radar timestamps & append to radar data
master_geo_ds_reindexed = master_geo_ds.reindex(
    dates=MISA_ds['dates'], method='ffill'
)
for var in master_geo_ds_reindexed.data_vars:
    MISA_ds[var] = master_geo_ds_reindexed[var]

# 7) Generate time‐lagged indices for feature engineering:
#    - AP at [0,3,5,6,7,9,12,24,48,72] hr prior
for lag in [0, 3, 5, 6, 7, 9, 12, 24, 48, 72]:
    master_geo_ds[f"ap_{lag}hr_prior"] = master_geo_ds['ap30'].interp(
        dates=master_geo_ds['dates'] - pd.Timedelta(f"{lag}H")
    )
#    - 24 hr & 48 hr prior for ap30, dst, sme, fism2
for var in ("ap30", "dst", "sme", "fism2"):
    master_geo_ds[f"{var}_24hr_prior"] = master_geo_ds[var].interp(
        dates=master_geo_ds['dates'] - pd.Timedelta("1D")
    )
    master_geo_ds[f"{var}_48hr_prior"] = master_geo_ds[var].interp(
        dates=master_geo_ds['dates'] - pd.Timedelta("2D")
    )
#    - HP at [0,3,6,9,12,24,48,72] hr prior
for lag in [0, 3, 6, 9, 12, 24, 48, 72]:
    master_geo_ds[f"hp_{lag}hr_prior"] = master_geo_ds['hp30'].interp(
        dates=master_geo_ds['dates'] - pd.Timedelta(f"{lag}H")
    )

# 8) Final align: nearest‐neighbor reindex within 1 hr tolerance and append these lagged vars
master_geo_ds_reindexed = master_geo_ds.reindex(
    dates=MISA_ds['dates'], method='nearest', tolerance=pd.Timedelta("1H")
)
for var in master_geo_ds_reindexed.data_vars:
    MISA_ds[var] = master_geo_ds_reindexed[var]

## PROCESSING AND SAVING ANCILLARY GRID DATASET ##
# grid_ds is used to compute bidirectional interpolators between (az, alt) ↔ (lat, lon)
# it is derived from MISA_ds as such
grid_ds = MISA_ds[['gdalt', 'az_normalized','glon','gdlat']]
grid_ds = grid_ds.where(
    (grid_ds['dates'].dt.date >= np.datetime64('2024-04-01')) &
    (grid_ds['dates'].dt.date <= np.datetime64('2024-04-30')),
    drop=True
)
grid_ds = grid_ds.where(
    (grid_ds['gdalt'] > 0) & (grid_ds['gdalt'] < 510),
    drop=True
)
grid_ds = grid_ds.where(
    (grid_ds['az_normalized'] > -145) & (grid_ds['az_normalized'] < -45),
    drop=True
)

## SAVING DATASETS ##
# save grid_ds to netCDF
grid_ds.to_netcdf(
    '../ancillary/processed_ncs/grid_ds_2.0.8.nc',
    format='NETCDF4', engine='netcdf4', unlimited_dims='dates'
)
# save MISA_ds to netCDF
MISA_ds.to_netcdf(
    '../ancillary/processed_ncs/misa_ds_2.0.8.nc',
    format='NETCDF4', engine='netcdf4', unlimited_dims='dates'
)
# save master_geo_ds to netCDF
master_geo_ds.to_netcdf(
    '../ancillary/processed_ncs/master_geo_ds_2.0.8.nc',
    format='NETCDF4', engine='netcdf4', unlimited_dims='dates'
)
# Out:
# Loading mlh021004g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021005g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021006g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021007g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021008g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021009g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021010g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021011g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021012g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021013g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021014g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021015g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021016g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021017g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021018g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021019g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021020g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021021g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021022g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021023g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021024g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021025g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021026g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021027g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021028g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021029g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021030g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021031g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021101g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021102g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021103g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh021104g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh030624g.003.hdf5...
# Loading mlh031021g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh031029g.004.hdf5...
# Loading mlh031030g.001.hdf5...
# Loading mlh031031g.001.hdf5...
# Loading mlh031101g.001.hdf5...
# Loading mlh031102g.001.hdf5...
# Loading mlh031103g.001.hdf5...
# Loading mlh031111g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh031120g.011.hdf5...
# Loading mlh031124g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh031208g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh031216g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040203g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040206g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040210g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040213g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040220g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040223g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040227g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040301g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040305g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040308g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040309g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040311g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040312g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040315g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040318g.001.hdf5...
# Loading mlh040319g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040325g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040329g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040330g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040331g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040401g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040402g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040403g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040405g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040415g.004.hdf5...
# Loading mlh040416g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040427g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040510g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040514g.005.hdf5...
# Loading mlh040517g.005.hdf5...
# Loading mlh040518g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040519g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040520g.002.hdf5...
# Loading mlh040521g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040524g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040614g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040707g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040716g.001.hdf5...
# Loading mlh040722g.005.hdf5...
# Loading mlh040723g.006.hdf5...
# Loading mlh040726g.001.hdf5...
# Loading mlh040809g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040910g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh040913g.005.hdf5...
# Loading mlh040920g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041018g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041022g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041025g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041105g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041109g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041203g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh041206g.001.hdf5...
# Loading mlh041207g.001.hdf5...
# Loading mlh041208g.001.hdf5...
# Loading mlh041209g.001.hdf5...
# Loading mlh050105g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050128g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050202g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050216g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050302g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050303g.001.hdf5...
# Loading mlh050317g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050323g.001.hdf5...
# Loading mlh050328g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050414g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050419g.001.hdf5...
# Loading mlh050429g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050517g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050613g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050622g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050714g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050810g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050818g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050831g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050901g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050902g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050903g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050904g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050905g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050906g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050907g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050908g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050909g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050910g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050911g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050912g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050913g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050914g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050915g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050916g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050917g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050918g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050919g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050920g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050921g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050922g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050923g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050924g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050925g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050926g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050927g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050928g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050929g.005.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh050930g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051005g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051108g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051116g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051117g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051207g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051208g.004.hdf5...
# Loading mlh051214g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051215g.003.hdf5...
# Loading mlh051216g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051217g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh051218g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060104g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060118g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060201g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060215g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060221g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060222g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060303g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060306g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060307g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060308g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060309g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060310g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060311g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060312g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060313g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060314g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060315g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060316g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060317g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060318g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060319g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060320g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060321g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060322g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060323g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060324g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060325g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060326g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060327g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060328g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060329g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060330g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060331g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060401g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060402g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060403g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060404g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060405g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060406g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060412g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060428g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060502g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060516g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060601g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060616g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060619g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060621g.003.hdf5...
# Loading mlh060622g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060626g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060706g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060707g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060731g.003.hdf5...
# Loading mlh060802g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060807g.001.hdf5...
# Loading mlh060808g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060809g.001.hdf5...
# Loading mlh060811g.001.hdf5...
# Loading mlh060812g.001.hdf5...
# Loading mlh060816g.003.hdf5...
# Loading mlh060818g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060913g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh060920g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh061024g.003.hdf5...
# Loading mlh061108g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh061117g.004.hdf5...
# Loading mlh061129g.004.hdf5...
# Loading mlh061206g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh061213g.003.hdf5...
# Loading mlh061220g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070110g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070120g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070126g.003.hdf5...
# Loading mlh070202g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070215g.003.hdf5...
# Loading mlh070228g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070301g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070315g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070329g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070412g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070426g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070501g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070510g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070524g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070607g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070618g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070620g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070705g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070719g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070802g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070816g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070822g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070830g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070911g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh070927g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071011g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071031g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071101g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071108g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071120g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071205g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071206g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh071211g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080117g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080118g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080119g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080120g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080121g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080122g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080123g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080124g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080125g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080126g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080127g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080128g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080129g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080130g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080131g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080201g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080213g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080228g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080313g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080327g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080403g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080408g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080522g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080603g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080619g.002.hdf5...
# Loading mlh080709g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080717g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080730g.002.hdf5...
# Loading mlh080801g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080814g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080819g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh080828g.002.hdf5...
# Loading mlh081016g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh081021g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh081028g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh081106g.004.hdf5...
# Loading mlh081107g.002.hdf5...
# Loading mlh081124g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh081204g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh081218g.004.hdf5...
# Loading mlh090126g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090204g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090211g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090219g.004.hdf5...
# Loading mlh090313g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090319g.002.hdf5...
# Loading mlh090323g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090324g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090326g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090327g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090331g.002.hdf5...
# Loading mlh090408g.004.hdf5...
# Loading mlh090423g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090511g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090512g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090520g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090527g.004.hdf5...
# Loading mlh090610g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090707g.002.hdf5...
# Loading mlh090712g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090713g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090715g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090717g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090724g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090812g.003.hdf5...
# Loading mlh090820g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090824g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090825g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090827g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090828g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090909g.002.hdf5...
# Loading mlh090914g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090915g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090916g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090917g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090918g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090919g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090920g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090921g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090922g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090923g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh090924g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh091015g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh091021g.002.hdf5...
# Loading mlh091104g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh091118g.002.hdf5...
# Loading mlh091202g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh091207g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh091217g.003.hdf5...
# Loading mlh100115g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100118g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100119g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100120g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100121g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100122g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100123g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100124g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100125g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100126g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100127g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100128g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100129g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100130g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100222g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100304g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100309g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100322g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100405g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100413g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100415g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100503g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100507g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100510g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100525g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100602g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100610g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100614g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100615g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100625g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100706g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100719g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100721g.001.hdf5...
# Loading mlh100728g.001.hdf5...
# Loading mlh100729g.001.hdf5...
# Loading mlh100730g.001.hdf5...
# Loading mlh100731g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100810g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100813g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100816g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100817g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100818g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100819g.002.hdf5...
# Loading mlh100820g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100826g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100901g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100907g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100927g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh100930g.002.hdf5...
# Loading mlh101005g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101012g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101014g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101015g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101022g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101026g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101028g.002.hdf5...
# Loading mlh101029g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101103g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101108g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101112g.002.hdf5...
# Loading mlh101115g.002.hdf5...
# Loading mlh101117g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101118g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101124g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101129g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101207g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh101216g.002.hdf5...
# Loading mlh110106g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110113g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110120g.002.hdf5...
# Loading mlh110201g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110202g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110203g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110204g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110205g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110206g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110207g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110208g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110210g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110211g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110214g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110215g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110216g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110217g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110218g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110219g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110223g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110304g.003.hdf5...
# Loading mlh110427g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110429g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110504g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110506g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110512g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110519g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110520g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110523g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110525g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110608g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110609g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110615g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110623g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110705g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110708g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110721g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110801g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110802g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110803g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110804g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110805g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110806g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110807g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110808g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110809g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110810g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110811g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110818g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110918g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110926g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh110929g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111017g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111025g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111027g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111110g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111128g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111129g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111130g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111201g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111208g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111222g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh111229g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120105g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120112g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120113g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120114g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120115g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120116g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120117g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120118g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120119g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120120g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120121g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120122g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120123g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120124g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120125g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120216g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120308g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120312g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120315g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120329g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120419g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120510g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120608g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120612g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120614g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120709g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120714g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120716g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120731g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120816g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120904g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120907g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120913g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh120930g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121001g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121011g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121025g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121101g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121120g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121127g.002.hdf5...
# Loading mlh121128g.002.hdf5...
# Loading mlh121206g.002.hdf5...
# Loading mlh121211g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121212g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121213g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh121214g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130104i.006.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130105g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130106g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130110g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130111g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130112g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130113g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130114g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130115g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130117g.002.hdf5...
# Loading mlh130124g.002.hdf5...
# Loading mlh130131g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130201g.002.hdf5...
# Loading mlh130207g.002.hdf5...
# Loading mlh130306g.002.hdf5...
# Loading mlh130307g.002.hdf5...
# Loading mlh130312g.002.hdf5...
# Loading mlh130314g.002.hdf5...
# Loading mlh130315g.005.hdf5...
# Loading mlh130316g.004.hdf5...
# Loading mlh130317g.005.hdf5...
# Loading mlh130327g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130412g.002.hdf5...
# Loading mlh130413g.002.hdf5...
# Loading mlh130416g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130417g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130418g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130419g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130426g.002.hdf5...
# Loading mlh130430g.002.hdf5...
# Loading mlh130503g.002.hdf5...
# Loading mlh130505g.002.hdf5...
# Loading mlh130506g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130513g.002.hdf5...
# Loading mlh130516g.002.hdf5...
# Loading mlh130519g.002.hdf5...
# Loading mlh130521g.002.hdf5...
# Loading mlh130523g.002.hdf5...
# Loading mlh130524g.002.hdf5...
# Loading mlh130530g.002.hdf5...
# Loading mlh130602g.002.hdf5...
# Loading mlh130606g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130611g.002.hdf5...
# Loading mlh130614g.002.hdf5...
# Loading mlh130618g.002.hdf5...
# Loading mlh130620g.002.hdf5...
# Loading mlh130621g.002.hdf5...
# Loading mlh130623g.002.hdf5...
# Loading mlh130626g.002.hdf5...
# Loading mlh130627g.002.hdf5...
# Loading mlh130708g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130709g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130710g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130711g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130712g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130718g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130730g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130801g.002.hdf5...
# Loading mlh130802g.002.hdf5...
# Loading mlh130805g.002.hdf5...
# Loading mlh130808g.002.hdf5...
# Loading mlh130811g.002.hdf5...
# Loading mlh130813g.002.hdf5...
# Loading mlh130814g.002.hdf5...
# Loading mlh130815g.002.hdf5...
# Loading mlh130816g.002.hdf5...
# Loading mlh130817g.002.hdf5...
# Loading mlh130820g.002.hdf5...
# Loading mlh130822g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh130823g.002.hdf5...
# Loading mlh130826g.002.hdf5...
# Loading mlh130829g.002.hdf5...
# Loading mlh130913g.002.hdf5...
# Loading mlh130926g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131002g.002.hdf5...
# Loading mlh131009g.002.hdf5...
# Loading mlh131010g.002.hdf5...
# Loading mlh131024g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131025g.003.hdf5...
# Loading mlh131104g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131105g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131106g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131107g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131120g.001.hdf5...
# Loading mlh131202g.003.hdf5...
# Loading mlh131205g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131217g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131218g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131219g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh131220g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140108g.004.hdf5...
# Loading mlh140219g.003.hdf5...
# Loading mlh140227g.004.hdf5...
# Loading mlh140331g.003.hdf5...
# Loading mlh140407g.003.hdf5...
# Loading mlh140408g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140409g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140410g.003.hdf5...
# Loading mlh140414g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140417g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140509g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140516g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140531g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140605g.003.hdf5...
# Loading mlh140619g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140620g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140703g.003.hdf5...
# Loading mlh140717g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140722g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140731g.003.hdf5...
# Loading mlh140814g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh140828g.003.hdf5...
# ...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220314g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220316g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220328g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220330g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220331g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220401g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220408g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220413g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220420g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220427g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220511g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220512g.003.hdf5...
# Loading mlh220518g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220527g.003.hdf5...
# Loading mlh220601g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220602g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220603g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220606g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220607g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220608g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220610g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220613g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220614g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220615g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220618g.003.hdf5...
# Loading mlh220621g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220622g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220623g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220624g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220625g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220706g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220707g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220708g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220718g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220719g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220728g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220803g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220811g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220817g.002.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220819g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220822a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220822g.001.hdf5...
# Loading mlh220823g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220824g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220829g.002.hdf5...
# Loading mlh220903g.002.hdf5...
# Loading mlh220915g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh220922g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221004g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221006a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221006b.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221006c.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221006g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221019g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221020g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221103g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh221116g.003.hdf5...
# Loading mlh230105g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230106g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230107g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230118g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230120g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230124g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230125g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230127g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230128g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230129g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230130g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230131g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230201g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230202g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230203g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230204g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230720g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230721g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230905g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230919g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230920g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230924g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh230928g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231014a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231014b.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231014c.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231014g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231017g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231024g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231026g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231102g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231107g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231111g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231114g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231116g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231121g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231130g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231201g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231207g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231214g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh231220g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240104g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240320g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240327g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240405g.003.hdf5...
# Loading mlh240406g.005.hdf5...
# Loading mlh240407g.005.hdf5...
# Loading mlh240408g.003.hdf5...
# Loading mlh240409g.003.hdf5...
# Loading mlh240410g.003.hdf5...
# Loading mlh240411g.007.hdf5...
# Loading mlh240412g.003.hdf5...
# Loading mlh240413g.003.hdf5...
# Loading mlh240414g.003.hdf5...
# Loading mlh240415g.003.hdf5...
# Loading mlh240416g.003.hdf5...
# Loading mlh240417g.004.hdf5...
# Loading mlh240418g.003.hdf5...
# Loading mlh240419g.004.hdf5...
# Loading mlh240420g.003.hdf5...
# Loading mlh240421g.001.hdf5...
# Loading mlh240422g.001.hdf5...
# Loading mlh240423g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240424g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240425g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240426g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240427g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240428g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240429g.004.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240430g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240501g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240530g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240603a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240603b.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240603c.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240603g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240604g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240605g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240606g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh240607g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh241206g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250110g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250113g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250114g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250115g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250121g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250122g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250123g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250124g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250125g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250126g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250127g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250128g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250129g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250130g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250131g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250311g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250314g.003.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250326g.003.hdf5...
# Loading mlh250327g.003.hdf5...
# Loading mlh250328g.003.hdf5...
# Loading mlh250329g.003.hdf5...
# Loading mlh250330g.003.hdf5...
# Loading mlh250331g.003.hdf5...
# Loading mlh250402g.003.hdf5...
# Loading mlh250403g.003.hdf5...
# Loading mlh250404g.003.hdf5...
# Loading mlh250405g.001.hdf5...
# Loading mlh250517g.001.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250518a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250518b.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250518c.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250519a.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250519b.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# Loading mlh250519c.000.hdf5...
# No matching group for kinst=31.0, mdtyp=115.0, pl=0.002
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:242: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   hp_ap_df = pd.read_csv(
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:260: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   f10_kp_df = pd.read_csv(
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:296: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dst_df = pd.read_csv(dst_dir, delim_whitespace=True, comment='#')
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:304: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   sme_30m  = sme_1m.resample('30T').max()
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:309: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if 'date' in ds.coords and ds.dims.get('date',0)==1:
# <frozen _collections_abc>:774: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:337: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   fism2_30m   = fism2_df_1m.resample('30T').max()
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3959585852.py:350: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   dates_full = pd.date_range(min(all_starts), max(all_ends), freq='30T')
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3575600058.py:60: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   dates=master_geo_ds['dates'] - pd.Timedelta(f"{lag}H")
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3575600058.py:73: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   dates=master_geo_ds['dates'] - pd.Timedelta(f"{lag}H")
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_58675/3575600058.py:78: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   dates=MISA_ds['dates'], method='nearest', tolerance=pd.Timedelta("1H")

# %%
### load preprocessed data (processed as illustrated above)
target_ds = xr.load_dataset('../ancillary/processed_ncs/MISA_ds_2.0.8.nc')
master_geo_ds = xr.load_dataset('../ancillary/processed_ncs/master_geo_ds_2.0.8.nc')
# remove duplicates from target_ds
target_ds = target_ds.isel(dates=~pd.Index(target_ds.dates.values).duplicated())

# %% [markdown]
# ## 2. Cleaning and Filtering

# %%
target_variable = 'te'

MISA_ds = target_ds.copy(deep=True)
# --- 1) LOAD & EXCLUDE UNWANTED DATES ---
# Load eclipse dates to mask out days with total or partial solar eclipse
eclipse_days_df = pd.read_csv('../ancillary/eclipse_days.csv')
eclipse_dates = pd.to_datetime(eclipse_days_df['Date'])

# Load extreme (storm) dates if you wanted to mask them (not used below but available)
extreme_days_df = pd.read_csv('../ancillary/extreme_days.csv')
extreme_dates = pd.to_datetime(extreme_days_df['Storm date'])

# Normalize radar timestamps to just the date (drop time component)
MISA_ds_dates_only = pd.to_datetime(MISA_ds['dates'].values).normalize()

# Mask out any rows whose date is in the eclipse list
MISA_ds = MISA_ds.sel(
    dates=~np.isin(MISA_ds_dates_only, eclipse_dates),
    drop=False
)

# Restrict to days between vernal equinox (Mar 20) and summer solstice (Jun 21)
MISA_ds = MISA_ds.where(
    (
        (MISA_ds['dates'].dt.month == 3) & (MISA_ds['dates'].dt.day >= 20)
    ) | (
        (MISA_ds['dates'].dt.month > 3) & (MISA_ds['dates'].dt.month < 6)
    ) | (
        (MISA_ds['dates'].dt.month == 6) & (MISA_ds['dates'].dt.day <= 21)
    )
)

# --- 2) DERIVE ADDITIONAL VARIABLES ---
# Compute electron temperature: te = tr * ti
MISA_ds['te']  = MISA_ds['tr'] * MISA_ds['ti']
# Compute delta electron temperature: dte = dtr * dti
MISA_ds['dte'] = MISA_ds['dtr'] * MISA_ds['dti']

# --- 3) COMPUTE RELATIVE ERROR FOR NE ---
dne      = MISA_ds[f'd{target_variable}'].values
ne_vals  = MISA_ds[target_variable].values
relerr_ne = dne / ne_vals

# --- 4) DEFINE PERCENTILE‐BASED OUTLIER DETECTOR ---
def filter_data_by_bins_indices(target_array, percentileRange, data=MISA_ds):
    """
    Identify outliers in `target_array` separately within each 100-km gdalt bin.

    For each bin of ground-to-scatter distance:
      1. Extract values in that range (drop NaNs).
      2. Compute the lower and upper percentiles (e.g., [5, 95]).
      3. Flag points below the lower or above the upper cutoff.
    
    Parameters
    ----------
    target_array : xarray.DataArray
        2D array of the variable to filter (dims: dates × range).
    percentileRange : list or tuple of two floats
        [lower_percentile, upper_percentile], e.g. [5, 95].
    data : xarray.Dataset
        Must contain 'gdalt' for bin definitions.
    
    Returns
    -------
    bad_indices : list of (row, col) tuples
        Coordinates of all flagged outlier points.
    """
    # Define 100-km altitude bins from 0 up to max+100
    gdalt_bins = np.arange(0, data['gdalt'].max().data + 100, 100)
    bad_indices = []

    # Loop through each bin interval
    for i in range(len(gdalt_bins) - 1):
        # Mask array to that bin
        bin_mask = (data['gdalt'] >= gdalt_bins[i]) & (data['gdalt'] < gdalt_bins[i + 1])
        binned = target_array.where(bin_mask, drop=False)

        # Flatten & drop NaNs for percentile computation
        flat = binned.data.flatten()
        flat = flat[~np.isnan(flat)]
        if flat.size < 2:
            continue  # skip bins with insufficient data

        # Compute percentile thresholds
        low, high = np.percentile(flat, percentileRange, method='inverted_cdf')

        # Flag points outside [low, high)
        mask_pct = (binned < low) | (binned >= high)
        rows, cols = np.where(mask_pct.data)
        bad_indices.extend(zip(rows, cols))

    return bad_indices

# --- 5) COLLECT ALL BAD‐POINT INDICES ---
# 5a) Points with >3% relative error
rel_err_bad_indices = np.argwhere(relerr_ne > 0.03)

# 5b) Points >3.67 std dev from mean in each column
std_bad_indices = std_column_filter_indices(MISA_ds[target_variable].data, nbstd=3.67)

# 5c) Points outside the 5th–95th percentile per altitude bin
percentile_bad_indices = filter_data_by_bins_indices(
    MISA_ds[target_variable], percentileRange=[5, 95]
)

# Combine into a unique set of (row, col) tuples
all_bad_indices = set(map(tuple, rel_err_bad_indices))
all_bad_indices.update(std_bad_indices)
all_bad_indices.update(percentile_bad_indices)

# --- 6) APPLY NaN MASK FOR ALL BAD POINTS ---
filtered_ne = MISA_ds[target_variable].data.copy()
filtered_ne = apply_nans(filtered_ne, list(all_bad_indices))

# --- 7) REPORT FILTERING RESULTS & UPDATE DATASET ---
orig_count     = np.count_nonzero(~np.isnan(MISA_ds[target_variable].data))
filtered_count = np.count_nonzero(~np.isnan(filtered_ne))
print(f"Original dataset size: {orig_count}")
print(f"Filtered dataset size: {filtered_count}")

# Overwrite 'ne' in MISA_ds with the cleaned array
MISA_ds[target_variable] = (('dates', 'range'), filtered_ne)
# Out:
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_13021/3419357777.py:42: RuntimeWarning: invalid value encountered in divide
#   relerr_ne = dne / ne_vals
# /var/folders/46/7rtdvrg92h175wj3d6dq0zjr0000gn/T/ipykernel_13021/3959585852.py:22: RuntimeWarning: Mean of empty slice
#   col_mean = np.nanmean(a[:, col])
# /Users/mateo/Documents/dev/Haystack/MISA_pySLIME/.venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# Original dataset size: 387029
# Filtered dataset size: 262694

# %% [markdown]
# ## 3. Transformation & Feature Engineering

# %%
# 1) Extract core coords & time indices from the cleaned dataset
dates_data     = MISA_ds['dates'].values                # (n_times,)
range_data     = MISA_ds['range'].values                # (n_range,)
normalized_az  = MISA_ds['az_normalized'].values       # mean beam azimuth (n_times,)
ut_data        = MISA_ds['ut'].values                   # universal time (decimal hours) (n_times,)

# 2) Flatten 2D fields (time × range) to 1D
flat_alt    = MISA_ds['gdalt'].values.flatten()    # ground-to-scatter distance
flat_gdlat  = MISA_ds['gdlat'].values.flatten()    # geomagnetic latitude
flat_glon   = MISA_ds['glon'].values.flatten()     # geomagnetic longitude
flat_doy    = MISA_ds['doy'].values.flatten()      # day-of-year

# 3) Repeat 1D arrays to align with each time-range pair
n_times = len(dates_data)
n_range = len(range_data)

dates_repeated = np.repeat(dates_data, n_range)      # timestamp per point
az_repeated    = np.repeat(normalized_az, n_range)   # az per point
ut_repeated    = np.repeat(ut_data, n_range)         # UT per point
doy_repeated   = np.repeat(flat_doy, n_range)        # DOY per point
range_repeated = np.tile(range_data, n_times)        # range per point

# 4) Prepare geophysical indices: repeat each time-series along range dim
geophysical_vars = [
    'dst','dst_24hr_prior','dst_48hr_prior',
    'sme','sme_24hr_prior','sme_48hr_prior',
    'fism2','fism2_24hr_prior','fism2_48hr_prior',
    'ap30','ap_3hr_prior','ap_5hr_prior','ap_6hr_prior',
    'ap_7hr_prior','ap_9hr_prior','ap_12hr_prior',
    'hp30','hp_3hr_prior','hp_6hr_prior','hp_9hr_prior','hp_12hr_prior'
]
flat_geophysical_data = []
for var in geophysical_vars:
    # Each series has length = n_times; repeat over n_range
    flat_geophysical_data.append(np.repeat(MISA_ds[var].values, n_range))

# 5) Correct Solar Local Time (SLT) from UT + lon/15, wrapping negatives
slt_corrected = ut_repeated + (flat_glon / 15)
neg_mask = slt_corrected < 0
# For points where SLT < 0, decrement the DOY by 1
doy_repeated[neg_mask] -= 1
# Wrap SLT into [0,24)
slt_corrected[neg_mask] += 24

# 5a) flatten the target variable (2D → 1D)
target_data = MISA_ds[target_variable].values.flatten()

# 6) Stack all inputs into a single dataframe (n_times*n_range × n_features)
combined_inputs_df = pd.DataFrame({
    'date': dates_repeated,
    'doy': doy_repeated,
    'slt': slt_corrected,
    'ut': ut_repeated,
    'range': range_repeated,
    'az': az_repeated,
    'alt': flat_alt,
    'lat': flat_gdlat,
    'lon': flat_glon,
    **{var: arr for var, arr in zip(geophysical_vars, flat_geophysical_data)},
    target_variable: target_data
})

combined_inputs_df = combined_inputs_df.dropna()

# %% [markdown]
# ## 3. Binned Regression Training

# %%
# remove a test day from training
test_date = np.datetime64('2024-04-07')
print(f'removing test day ({test_date}) from dataset.')
entries = np.sum(~np.isnan(combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') == test_date))) # remove april 12th
if entries.sum() > 0:
    combined_inputs_df = combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') != test_date) # remove test day
    print(f'{entries} dataset entries removed.')
else:
    print('no entries removed.')
    test_date = np.datetime64('2024-04-08')
print(f'removing test day ({test_date}) from dataset.')
entries = np.sum(~np.isnan(combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') == test_date))) # remove april 12th
if entries.sum() > 0:
    combined_inputs_df = combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') != test_date) # remove test day
    print(f'{entries} dataset entries removed.')
else:
    print('no entries removed.')
    test_date = np.datetime64('2024-04-09')
print(f'removing test day ({test_date}) from dataset.')
entries = np.sum(~np.isnan(combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') == test_date))) # remove april 12th
if entries.sum() > 0:
    combined_inputs_df = combined_inputs_df.where(combined_inputs_df['date'].dt.floor(freq='1D') != test_date) # remove test day
    print(f'{entries} dataset entries removed.')
else:
    print('no entries removed.')
# Out:
# removing test day (2024-04-07) from dataset.
# date                11318
# doy                 11318
# slt                 11318
# ut                  11318
# range               11318
# az                  11318
# alt                 11318
# lat                 11318
# lon                 11318
# dst                 11318
# dst_24hr_prior      11318
# dst_48hr_prior      11318
# sme                 11318
# sme_24hr_prior      11318
# sme_48hr_prior      11318
# fism2               11318
# fism2_24hr_prior    11318
# fism2_48hr_prior    11318
# ap30                11318
# ap_3hr_prior        11318
# ap_5hr_prior        11318
# ap_6hr_prior        11318
# ap_7hr_prior        11318
# ap_9hr_prior        11318
# ap_12hr_prior       11318
# hp30                11318
# hp_3hr_prior        11318
# hp_6hr_prior        11318
# hp_9hr_prior        11318
# hp_12hr_prior       11318
# te                  11318
# dtype: int64 dataset entries removed.
# removing test day (2024-04-07) from dataset.
# no entries removed.
# removing test day (2024-04-09) from dataset.
# date                23
# doy                 23
# slt                 23
# ut                  23
# range               23
# az                  23
# alt                 23
# lat                 23
# lon                 23
# dst                 23
# dst_24hr_prior      23
# dst_48hr_prior      23
# sme                 23
# sme_24hr_prior      23
# sme_48hr_prior      23
# fism2               23
# fism2_24hr_prior    23
# fism2_48hr_prior    23
# ap30                23
# ap_3hr_prior        23
# ap_5hr_prior        23
# ap_6hr_prior        23
# ap_7hr_prior        23
# ap_9hr_prior        23
# ap_12hr_prior       23
# hp30                23
# hp_3hr_prior        23
# hp_6hr_prior        23
# hp_9hr_prior        23
# hp_12hr_prior       23
# te                  23
# dtype: int64 dataset entries removed.
# /Users/mateo/Documents/dev/Haystack/MISA_pySLIME/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Users/mateo/Documents/dev/Haystack/MISA_pySLIME/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Users/mateo/Documents/dev/Haystack/MISA_pySLIME/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# === TRAINING: Binned Polynomial Ridge Regression for each (az, alt) cell ===

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Ridge

# 1) Prepare the DataFrame and restrict to your best-performing az/alt domain
target_df = combined_inputs_df.copy(deep=True)

# Define the “core” azimuth & altitude ranges + a small buffer
set_az_domain  = (-140, -40)  # degrees
set_alt_domain = (100,  500)  # km
buffer = 5                    # slack outside the selected domain

# Mask out rows outside the buffered az/alt region
target_df = target_df.where(
    (target_df['az']  > set_az_domain[0] - buffer) &
    (target_df['az']  <= set_az_domain[1] + buffer) &
    (target_df['alt'] > set_alt_domain[0] - buffer) &
    (target_df['alt'] < set_alt_domain[1] + buffer * 5)
)

# 2) Define the bin edges for azimuth & altitude based on grid-search results
target_dAz  = 6.5   # bin width in degrees
target_dAlt = 28    # bin width in km

az_bin_edges  = np.arange(set_az_domain[0], set_az_domain[1] + target_dAz, target_dAz)
alt_bin_edges = np.arange(set_alt_domain[0], set_alt_domain[1] + target_dAlt, target_dAlt)

# Assign each row to an integer bin index
target_df['az_bin']  = pd.cut(target_df['az'],  bins=az_bin_edges,  labels=False, right=False)
target_df['alt_bin'] = pd.cut(target_df['alt'], bins=alt_bin_edges, labels=False, right=False)

# 3) Specify input features and the target variable for regression
target_indices_list = ['fism2_48hr_prior', 'ap_7hr_prior']
features = ['doy', 'slt'] + target_indices_list
target   = target_variable  # e.g., 'ne'

# 4) Prepare dictionaries to collect models and (optionally) debug info
debug_bin_data = {}     # store train/test splits for a specific bin if needed
bin_models     = {}     # final storage for (scaler, poly, model) per bin

# 5) Loop over each (az_bin, alt_bin) cell
for (az_bin, alt_bin), group in target_df.groupby(['az_bin', 'alt_bin']):

    # Skip bins with too few samples to fit a reliable model
    if len(group) <= 5:
        continue

    # Extract feature matrix X and target vector y for this bin
    X_bin = group[features].values
    y_bin = group[target].values

    # Split into train/test (33% for testing)
    X_train_bin, X_test_bin, y_train_bin, y_test_bin = train_test_split(
        X_bin, y_bin, test_size=0.33, random_state=42
    )

    # Compute the actual physical ranges of this bin (for metadata)
    az_range  = (az_bin_edges[int(az_bin)],   az_bin_edges[int(az_bin) + 1])
    alt_range = (alt_bin_edges[int(alt_bin)], alt_bin_edges[int(alt_bin) + 1])

    # Optional DEBUGGING: capture the splits for one “interesting” bin
    # if (az_range and alt_range near your test_az, test_alt):
    #     debug_bin_data = {
    #         'X_train': X_train_bin, 'y_train': y_train_bin,
    #         'X_test':  X_test_bin,  'y_test':  y_test_bin,
    #         'az_range': az_range, 'alt_range': alt_range,
    #         'n_samples': len(group)
    #     }

    # 6) Standardize inputs (zero mean, unit variance) based on training data
    scaler_bin = StandardScaler()
    X_train_scaled = scaler_bin.fit_transform(X_train_bin)

    # 7) Expand features into polynomial terms (up to 4th degree)
    poly_bin = PolynomialFeatures(degree=4, include_bias=False)
    X_train_poly = poly_bin.fit_transform(X_train_scaled)

    # 8) Fit a Ridge regression (L2-regularized linear model)
    model_bin = Ridge(alpha=1.0)
    model_bin.fit(X_train_poly, y_train_bin)

    # 9) Save the components for this bin to be used later in prediction
    bin_models[(az_bin, alt_bin)] = {
        'model':   model_bin,
        'scaler':  scaler_bin,
        'poly':    poly_bin,
        'az_range': az_range,
        'alt_range': alt_range,
        'n_samples': len(group)
    }

# %%
np.save(f'../model/{target_variable}_model_2_0_8.npy', bin_models)
